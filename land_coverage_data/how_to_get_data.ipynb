# %%
# %load_ext autoreload
# %autoreload 2

# %%
from land_coverage import get_data, get_map
import matplotlib.pyplot as plt

# %%
paris_gpd = get_data()

# %%
paris_gpd.head()
# Out:
#    OBJECTID  c_zonage c_zonage_brut  Shape_Length    Shape_Area  \
# 0    116260         3          UEL1    190.138408   1790.746846
# 1    116261         5            UF    730.014425  13519.202675
# 2    116262         3            UM     96.071430    534.197866
# 3    116263         7            U6    729.153446  30753.935854
# 4    116264         6            UB   1014.674374  22111.953704
#
#               categories                                           geometry
# 0       Residential Zone  POLYGON ((2.17655 48.88660, 2.17664 48.88667, ...
# 1       Dense Mixed Zone  POLYGON ((2.29638 48.81655, 2.29663 48.81670, ...
# 2       Residential Zone  POLYGON ((2.43997 48.85262, 2.43973 48.85264, ...
# 3  Public Infrastructure  POLYGON ((2.48415 48.81079, 2.48407 48.81067, ...
# 4  Semi-Dense Mixed Zone  POLYGON ((2.47546 48.87302, 2.47513 48.87311, ...

# %%
map = get_map(paris_gpd)
